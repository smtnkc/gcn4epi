# %% [markdown]
# **[iEnhancer-2L](https://academic.oup.com/bioinformatics/article/32/3/362/1744331)** ➡ H1ES, **K562**, **GM12878**, HepG2, **HUVEC**, HSMM, NHLF, **NHEK**, HMEC
#
# **[TargetFinder](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4910881/)** ➡ **GM12878**, **K562**, IMR90, HeLa-S3, **HUVEC**, **NHEK**

# %%
import os
import sys
import random
import re
import numpy as np
import pandas as pd
import pickle as pkl
from IPython.display import display

CELL_LINE = 'combined'

# %%
ep_pairs = pd.read_csv('https://raw.githubusercontent.com/shwhalen/' \
                               'targetfinder/master/paper/targetfinder/{}/' \
                               'output-ep/pairs.csv'.format(CELL_LINE))

# %%
ep_pairs = ep_pairs[ep_pairs['label'] == 1].reset_index(drop=True)
ep_pairs = ep_pairs[['enhancer_name', 'enhancer_chrom', 'enhancer_start', 'enhancer_end',
                    'promoter_name', 'promoter_chrom', 'promoter_start', 'promoter_end', 'label']]

display(ep_pairs)
# Out:
#                        enhancer_name enhancer_chrom  enhancer_start  \
# 0          K562|chr1:6454864-6455189           chr1         6454864
# 1          K562|chr1:9935400-9935544           chr1         9935400
# 2          K562|chr1:9935400-9935544           chr1         9935400
# 3        K562|chr1:16399567-16400081           chr1        16399567
# 4        K562|chr1:16400449-16400658           chr1        16400449
# ...                              ...            ...             ...
# 7079    IMR90|chrX:17609600-17610400           chrX        17609600
# 7080    IMR90|chrX:23919400-23919600           chrX        23919400
# 7081    IMR90|chrX:47383600-47383800           chrX        47383600
# 7082  IMR90|chrX:109083200-109084400           chrX       109083200
# 7083  IMR90|chrX:109084400-109085400           chrX       109084400
#
#       enhancer_end                   promoter_name promoter_chrom  \
# 0          6455189       K562|chr1:6613082-6615021           chr1
# 1          9935544     K562|chr1:10002482-10004387           chr1
# 2          9935544     K562|chr1:10092884-10095822           chr1
# 3         16400081     K562|chr1:16677563-16679703           chr1
# 4         16400658     K562|chr1:16677563-16679703           chr1
# ...            ...                             ...            ...
# 7079      17610400    IMR90|chrX:17393000-17393600           chrX
# 7080      23919600    IMR90|chrX:23801000-23801800           chrX
# 7081      47383800    IMR90|chrX:47050000-47050600           chrX
# 7082     109084400  IMR90|chrX:108976400-108976800           chrX
# 7083     109085400  IMR90|chrX:108976400-108976800           chrX
#
#       promoter_start  promoter_end  label
# 0            6613082       6615021      1
# 1           10002482      10004387      1
# 2           10092884      10095822      1
# 3           16677563      16679703      1
# 4           16677563      16679703      1
# ...              ...           ...    ...
# 7079        17393000      17393600      1
# 7080        23801000      23801800      1
# 7081        47050000      47050600      1
# 7082       108976400     108976800      1
# 7083       108976400     108976800      1
#
# [7084 rows x 9 columns]

# %%
print("{} unique enhancers".format(len(set(ep_pairs['enhancer_name']))))
# Out:
# 6493 unique enhancers

# %%
types = ['strong', 'weak', 'non']

for t in types:
    data = re.split(r'(^>.*)', ''.join(open('data/{}_enhancers.txt'.format(t)).readlines()), flags=re.M)
    fids = []
    seqs = []
    for i in range(2, len(data), 2):
        fids.append(data[i-1][1:])
        seqs.append(data[i].replace('\n', ''))

    n_matches = 0

    for fid in fids:
        x = fid.split('_')
        match = ep_pairs.loc[(ep_pairs['enhancer_chrom'].str.upper() == x[0]) & 
                               (ep_pairs['enhancer_start'] <= int(x[1])) &
                               (ep_pairs['enhancer_end'] >= int(x[2]))]['enhancer_name'].values
        if len(match) > 0:
            n_matches = n_matches + len(match)
            # print(match)

    print("{} enhancer\n{} out of {} -> {:.2f}%\n".format(t, n_matches, len(fids), n_matches*100/len(fids)))
# Out:
# strong enhancer
# 18 out of 742 -> 2.43%
#
# weak enhancer
# 105 out of 742 -> 14.15%
#
# non enhancer
# 508 out of 1484 -> 34.23%
